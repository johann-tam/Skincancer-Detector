# %%
"""
author: Johann Tammen
purpose: Put images in directories based on their label

Prerequisites:  - Have all images in one folder called "all-images'
                - Have metadata.csv file available with the correct label for each image
"""

try:
    import hugsvision
except:
    # !pip install -q hugsvision
    import hugsvision

print(hugsvision.__version__)
# Out:
# 0.71

# %%
import os
import shutil
import pandas as pd
metadata = pd.read_csv("metadata.csv").set_index('image_id').T.to_dict('list')
for current_dir in ["all-images"]:
    for image_path in os.listdir(current_dir):
        label = metadata[image_path.split(".")[0]][1]
        print(label)
        os.makedirs("./HAM10000/" + label, exist_ok=True)
        shutil.copy2(current_dir + "/" + image_path, "./HAM10000/" + label + "/" + image_path)
# Out:
# nv
# nv
# nv
# nv
# bkl
# nv
# nv
# nv
# bkl
# mel
# bcc
# nv
# bkl
# nv
# nv
# nv
# nv
# akiec
# mel
# nv
# nv
# nv
# nv
# df
# mel
# nv
# nv
# nv
# nv
# nv
# nv
# nv
# bkl
# nv
# nv
# bkl
# bkl
# mel
# nv
# akiec
# nv
# nv
# nv
# nv
# nv
# nv
# bkl
# nv
# nv
# akiec
# mel
# nv
# nv
# nv
# bkl
# nv
# nv
# vasc
# nv
# mel
# nv
# nv
# nv
# nv
# nv
# bcc
# mel
# mel
# nv
# nv
# nv
# mel
# nv
# mel
# nv
# nv
# nv
# nv
# nv
# nv
# nv
# nv
# vasc
# nv
# nv
# nv
# nv
# vasc
# nv
# nv
# nv
# nv
# nv
# nv
# nv
# nv
# akiec
# nv
# nv
# nv
# bcc
# nv
# nv
# mel
# nv
# nv
# bcc
# nv
# bkl
# nv
# mel
# nv
# nv
# bkl
# nv
# nv
# nv
# nv
# bkl
# nv
# nv
# nv
# akiec
# nv
# nv
# mel
# nv
# nv
# nv
# nv
# nv
# bcc
# nv
# nv
# nv
# nv
# nv
# mel
# nv
# mel
# mel
# bkl
# bkl
# nv
# mel
# akiec
# nv
# nv
# nv
# nv
# nv
# nv
# nv
# nv
# bkl
# df
# bkl
# mel
# nv
# nv
# nv
# bcc
# nv
# nv
# nv
# nv
# nv
# nv
# nv
# nv
# nv
# nv
# bcc
# bkl
# nv
# nv
# nv
# nv
# nv
# bcc
# nv
# nv
# nv
# bkl
# nv
# nv
# ...
